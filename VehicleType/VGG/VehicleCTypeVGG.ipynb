# %%
'''
使用VGG做车型分析
'''
# 导入包
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# 设置参数
num_classes = 4
LR = 0.001
num_epochs = 100

print(device)
# Out:
# cuda

# %% [markdown]
# #### 加载数据集

# %%
# 定义同样的图像转换
transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = ImageFolder('../TypeData', transform=transform)
train_size = int(0.75 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# #### 定义网络结构

# %%
# 加载模型
# Define the MiniVGGNet model
class MiniVGGNet(nn.Module):
    def __init__(self, num_classes = 4):
        super(MiniVGGNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.25)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU()
        self.bn4 = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.25)
        self.fc1 = nn.Linear(64*8*8, 512)
        self.relu5 = nn.ReLU()
        self.bn5 = nn.BatchNorm1d(512)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(512, num_classes)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        # first CONV => RELU => CONV => RELU => POOL layer set
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.bn1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.bn2(x)
        x = self.pool1(x)
        x = self.dropout1(x)

        # second CONV => RELU => CONV => RELU => POOL layer set
        x = self.conv3(x)
        x = self.relu3(x)
        x = self.bn3(x)
        x = self.conv4(x)
        x = self.relu4(x)
        x = self.bn4(x)
        x = self.pool2(x)
        x = self.dropout2(x)

        # first (and only) set of FC => RELU layers
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.relu5(x)
        x = self.bn5(x)
        x = self.dropout3(x)

        # softmax classifier
        x = self.fc2(x)
        x = self.softmax(x)

        # return the constructed network architecture
        return x

# %% [markdown]
# #### 训练模型

# %%
import os
import torch
import torch.nn as nn

def train_and_evaluate_model(model, train_loader, test_loader, criterion, optimizer, device, num_epochs=50, save_path="./models/vehicleType.pth"):

    train_loss_list = []
    train_acc_list = []
    test_loss_list = []
    test_acc_list = []
    best_acc = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        train_correct = 0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            train_correct += (predicted == labels).sum().item()

        train_loss /= len(train_loader)
        train_acc = train_correct / len(train_loader.dataset)
        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)

        # ---------- 验证 ----------
        model.eval()
        test_loss = 0
        test_correct = 0

        with torch.no_grad():
            for images, labels in test_loader:
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                test_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                test_correct += (predicted == labels).sum().item()

        test_loss /= len(test_loader)
        test_acc = test_correct / len(test_loader.dataset)
        test_loss_list.append(test_loss)
        test_acc_list.append(test_acc)

        print(f"Epoch [{epoch+1}/{num_epochs}]")
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test  Loss: {test_loss:.4f}, Test  Acc: {test_acc:.4f}")

        # ---------- 保存最优模型 ----------
        if test_acc > best_acc:
            best_acc = test_acc
            os.makedirs(os.path.dirname(save_path), exist_ok=True)
            torch.save(model.state_dict(), save_path)

    return train_loss_list, train_acc_list, test_loss_list, test_acc_list, best_acc

# %%
model = MiniVGGNet(num_classes).to(device)

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=LR)

# %%
train_loss_list, train_acc_list, test_loss_list, test_acc_list, best_acc= train_and_evaluate_model(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    criterion=criterion,
    optimizer=optimizer,
    device=device,
    num_epochs=num_epochs,
    save_path='./models/vehicleType.pth'
)
# Out:
# Epoch [1/100]
# Train Loss: 0.9381, Train Acc: 0.8379, Test  Loss: 0.8838, Test  Acc: 0.9344
# Epoch [2/100]
# Train Loss: 0.8182, Train Acc: 0.9478, Test  Loss: 0.8098, Test  Acc: 0.9426
# Epoch [3/100]
# Train Loss: 0.7974, Train Acc: 0.9643, Test  Loss: 0.7966, Test  Acc: 0.9672
# Epoch [4/100]
# Train Loss: 0.7932, Train Acc: 0.9643, Test  Loss: 0.8148, Test  Acc: 0.9344
# Epoch [5/100]
# Train Loss: 0.7821, Train Acc: 0.9670, Test  Loss: 0.8385, Test  Acc: 0.9098
# Epoch [6/100]
# Train Loss: 0.7764, Train Acc: 0.9780, Test  Loss: 0.7991, Test  Acc: 0.9508
# Epoch [7/100]
# Train Loss: 0.7609, Train Acc: 0.9945, Test  Loss: 0.7807, Test  Acc: 0.9672
# Epoch [8/100]
# Train Loss: 0.7595, Train Acc: 0.9835, Test  Loss: 0.7718, Test  Acc: 0.9754
# Epoch [9/100]
# Train Loss: 0.7637, Train Acc: 0.9808, Test  Loss: 0.7795, Test  Acc: 0.9590
# Epoch [10/100]
# Train Loss: 0.7552, Train Acc: 0.9918, Test  Loss: 0.7715, Test  Acc: 0.9754
# Epoch [11/100]
# Train Loss: 0.7505, Train Acc: 0.9973, Test  Loss: 0.7713, Test  Acc: 0.9754
# Epoch [12/100]
# Train Loss: 0.7569, Train Acc: 0.9890, Test  Loss: 0.7713, Test  Acc: 0.9754
# Epoch [13/100]
# Train Loss: 0.7492, Train Acc: 0.9945, Test  Loss: 0.7739, Test  Acc: 0.9754
# Epoch [14/100]
# Train Loss: 0.7531, Train Acc: 0.9918, Test  Loss: 0.7715, Test  Acc: 0.9836
# Epoch [15/100]
# Train Loss: 0.7504, Train Acc: 0.9973, Test  Loss: 0.7694, Test  Acc: 0.9836
# Epoch [16/100]
# Train Loss: 0.7577, Train Acc: 0.9890, Test  Loss: 0.7687, Test  Acc: 0.9754
# Epoch [17/100]
# Train Loss: 0.7477, Train Acc: 0.9973, Test  Loss: 0.7627, Test  Acc: 0.9918
# Epoch [18/100]
# Train Loss: 0.7517, Train Acc: 0.9945, Test  Loss: 0.7617, Test  Acc: 0.9836
# Epoch [19/100]
# Train Loss: 0.7496, Train Acc: 0.9945, Test  Loss: 0.7798, Test  Acc: 0.9754
# Epoch [20/100]
# Train Loss: 0.7471, Train Acc: 1.0000, Test  Loss: 0.7634, Test  Acc: 0.9918
# Epoch [21/100]
# Train Loss: 0.7521, Train Acc: 0.9945, Test  Loss: 0.7765, Test  Acc: 0.9672
# Epoch [22/100]
# Train Loss: 0.7489, Train Acc: 0.9973, Test  Loss: 0.7730, Test  Acc: 0.9754
# Epoch [23/100]
# Train Loss: 0.7495, Train Acc: 1.0000, Test  Loss: 0.7796, Test  Acc: 0.9672
# Epoch [24/100]
# Train Loss: 0.7515, Train Acc: 0.9973, Test  Loss: 0.7678, Test  Acc: 0.9836
# Epoch [25/100]
# Train Loss: 0.7507, Train Acc: 0.9973, Test  Loss: 0.7684, Test  Acc: 0.9754
# Epoch [26/100]
# Train Loss: 0.7485, Train Acc: 0.9973, Test  Loss: 0.7640, Test  Acc: 0.9836
# Epoch [27/100]
# Train Loss: 0.7530, Train Acc: 0.9890, Test  Loss: 0.7669, Test  Acc: 0.9754
# Epoch [28/100]
# Train Loss: 0.7560, Train Acc: 0.9918, Test  Loss: 0.7987, Test  Acc: 0.9426
# Epoch [29/100]
# Train Loss: 0.7560, Train Acc: 0.9890, Test  Loss: 0.7622, Test  Acc: 0.9836
# Epoch [30/100]
# Train Loss: 0.7525, Train Acc: 0.9945, Test  Loss: 0.7582, Test  Acc: 0.9918
# Epoch [31/100]
# Train Loss: 0.7481, Train Acc: 0.9973, Test  Loss: 0.7666, Test  Acc: 0.9836
# Epoch [32/100]
# Train Loss: 0.7460, Train Acc: 1.0000, Test  Loss: 0.7715, Test  Acc: 0.9754
# Epoch [33/100]
# Train Loss: 0.7593, Train Acc: 0.9808, Test  Loss: 0.7821, Test  Acc: 0.9590
# Epoch [34/100]
# Train Loss: 0.7565, Train Acc: 0.9918, Test  Loss: 0.7816, Test  Acc: 0.9754
# Epoch [35/100]
# Train Loss: 0.7582, Train Acc: 0.9835, Test  Loss: 0.7974, Test  Acc: 0.9508
# Epoch [36/100]
# Train Loss: 0.7570, Train Acc: 0.9890, Test  Loss: 0.7649, Test  Acc: 0.9836
# Epoch [37/100]
# Train Loss: 0.7497, Train Acc: 0.9973, Test  Loss: 0.7718, Test  Acc: 0.9754
# Epoch [38/100]
# Train Loss: 0.7547, Train Acc: 0.9918, Test  Loss: 0.7682, Test  Acc: 0.9836
# Epoch [39/100]
# Train Loss: 0.7489, Train Acc: 0.9973, Test  Loss: 0.7694, Test  Acc: 0.9754
# Epoch [40/100]
# Train Loss: 0.7549, Train Acc: 0.9890, Test  Loss: 0.7677, Test  Acc: 0.9836
# Epoch [41/100]
# Train Loss: 0.7540, Train Acc: 0.9945, Test  Loss: 0.7805, Test  Acc: 0.9590
# Epoch [42/100]
# Train Loss: 0.7535, Train Acc: 0.9973, Test  Loss: 0.7664, Test  Acc: 0.9836
# Epoch [43/100]
# Train Loss: 0.7515, Train Acc: 0.9945, Test  Loss: 0.7732, Test  Acc: 0.9672
# Epoch [44/100]
# Train Loss: 0.7469, Train Acc: 1.0000, Test  Loss: 0.7743, Test  Acc: 0.9672
# Epoch [45/100]
# Train Loss: 0.7510, Train Acc: 0.9918, Test  Loss: 0.7688, Test  Acc: 0.9754
# Epoch [46/100]
# Train Loss: 0.7615, Train Acc: 0.9808, Test  Loss: 0.7867, Test  Acc: 0.9508
# Epoch [47/100]
# Train Loss: 0.7532, Train Acc: 0.9945, Test  Loss: 0.7710, Test  Acc: 0.9754
# Epoch [48/100]
# Train Loss: 0.7481, Train Acc: 0.9973, Test  Loss: 0.7732, Test  Acc: 0.9754
# Epoch [49/100]
# Train Loss: 0.7556, Train Acc: 0.9890, Test  Loss: 0.7541, Test  Acc: 0.9918
# Epoch [50/100]
# Train Loss: 0.7529, Train Acc: 0.9890, Test  Loss: 0.7530, Test  Acc: 0.9918
# Epoch [51/100]
# Train Loss: 0.7550, Train Acc: 0.9890, Test  Loss: 0.7545, Test  Acc: 0.9918
# Epoch [52/100]
# Train Loss: 0.7482, Train Acc: 0.9973, Test  Loss: 0.7608, Test  Acc: 0.9836
# Epoch [53/100]
# Train Loss: 0.7480, Train Acc: 0.9945, Test  Loss: 0.7760, Test  Acc: 0.9754
# Epoch [54/100]
# Train Loss: 0.7490, Train Acc: 0.9945, Test  Loss: 0.7751, Test  Acc: 0.9672
# Epoch [55/100]
# Train Loss: 0.7473, Train Acc: 0.9973, Test  Loss: 0.7710, Test  Acc: 0.9672
# Epoch [56/100]
# Train Loss: 0.7448, Train Acc: 1.0000, Test  Loss: 0.7688, Test  Acc: 0.9754
# Epoch [57/100]
# Train Loss: 0.7468, Train Acc: 0.9973, Test  Loss: 0.7707, Test  Acc: 0.9836
# Epoch [58/100]
# Train Loss: 0.7439, Train Acc: 1.0000, Test  Loss: 0.7646, Test  Acc: 0.9754
# Epoch [59/100]
# Train Loss: 0.7465, Train Acc: 0.9973, Test  Loss: 0.7678, Test  Acc: 0.9754
# Epoch [60/100]
# Train Loss: 0.7467, Train Acc: 0.9973, Test  Loss: 0.7720, Test  Acc: 0.9754
# Epoch [61/100]
# Train Loss: 0.7483, Train Acc: 0.9973, Test  Loss: 0.7733, Test  Acc: 0.9672
# Epoch [62/100]
# Train Loss: 0.7463, Train Acc: 1.0000, Test  Loss: 0.7731, Test  Acc: 0.9754
# Epoch [63/100]
# Train Loss: 0.7475, Train Acc: 0.9973, Test  Loss: 0.7556, Test  Acc: 0.9918
# Epoch [64/100]
# Train Loss: 0.7443, Train Acc: 1.0000, Test  Loss: 0.7547, Test  Acc: 0.9918
# Epoch [65/100]
# Train Loss: 0.7454, Train Acc: 1.0000, Test  Loss: 0.7729, Test  Acc: 0.9754
# Epoch [66/100]
# Train Loss: 0.7447, Train Acc: 1.0000, Test  Loss: 0.7662, Test  Acc: 0.9754
# Epoch [67/100]
# Train Loss: 0.7442, Train Acc: 1.0000, Test  Loss: 0.7572, Test  Acc: 0.9918
# Epoch [68/100]
# Train Loss: 0.7459, Train Acc: 0.9973, Test  Loss: 0.7538, Test  Acc: 0.9918
# Epoch [69/100]
# Train Loss: 0.7446, Train Acc: 1.0000, Test  Loss: 0.7542, Test  Acc: 0.9918
# Epoch [70/100]
# Train Loss: 0.7439, Train Acc: 1.0000, Test  Loss: 0.7552, Test  Acc: 0.9918
# Epoch [71/100]
# Train Loss: 0.7443, Train Acc: 1.0000, Test  Loss: 0.7685, Test  Acc: 0.9754
# Epoch [72/100]
# Train Loss: 0.7461, Train Acc: 0.9973, Test  Loss: 0.7525, Test  Acc: 0.9918
# Epoch [73/100]
# Train Loss: 0.7454, Train Acc: 0.9973, Test  Loss: 0.7761, Test  Acc: 0.9672
# Epoch [74/100]
# Train Loss: 0.7454, Train Acc: 1.0000, Test  Loss: 0.7603, Test  Acc: 0.9836
# Epoch [75/100]
# Train Loss: 0.7461, Train Acc: 0.9973, Test  Loss: 0.7630, Test  Acc: 0.9754
# Epoch [76/100]
# Train Loss: 0.7446, Train Acc: 1.0000, Test  Loss: 0.7843, Test  Acc: 0.9672
# Epoch [77/100]
# Train Loss: 0.7510, Train Acc: 0.9945, Test  Loss: 0.7814, Test  Acc: 0.9590
# Epoch [78/100]
# Train Loss: 0.7482, Train Acc: 0.9973, Test  Loss: 0.7821, Test  Acc: 0.9590
# Epoch [79/100]
# Train Loss: 0.7465, Train Acc: 0.9973, Test  Loss: 0.7625, Test  Acc: 0.9836
# Epoch [80/100]
# Train Loss: 0.7460, Train Acc: 0.9973, Test  Loss: 0.7784, Test  Acc: 0.9672
# Epoch [81/100]
# Train Loss: 0.7444, Train Acc: 1.0000, Test  Loss: 0.7806, Test  Acc: 0.9672
# Epoch [82/100]
# Train Loss: 0.7459, Train Acc: 0.9973, Test  Loss: 0.7854, Test  Acc: 0.9590
# Epoch [83/100]
# Train Loss: 0.7484, Train Acc: 0.9945, Test  Loss: 0.7618, Test  Acc: 0.9836
# Epoch [84/100]
# Train Loss: 0.7448, Train Acc: 1.0000, Test  Loss: 0.7670, Test  Acc: 0.9836
# Epoch [85/100]
# Train Loss: 0.7443, Train Acc: 1.0000, Test  Loss: 0.7651, Test  Acc: 0.9754
# Epoch [86/100]
# Train Loss: 0.7446, Train Acc: 1.0000, Test  Loss: 0.7552, Test  Acc: 0.9918
# Epoch [87/100]
# Train Loss: 0.7446, Train Acc: 1.0000, Test  Loss: 0.7652, Test  Acc: 0.9836
# Epoch [88/100]
# Train Loss: 0.7477, Train Acc: 0.9973, Test  Loss: 0.7670, Test  Acc: 0.9836
# Epoch [89/100]
# Train Loss: 0.7473, Train Acc: 0.9973, Test  Loss: 0.7882, Test  Acc: 0.9508
# Epoch [90/100]
# Train Loss: 0.7451, Train Acc: 1.0000, Test  Loss: 0.7547, Test  Acc: 0.9918
# Epoch [91/100]
# Train Loss: 0.7450, Train Acc: 1.0000, Test  Loss: 0.7670, Test  Acc: 0.9754
# Epoch [92/100]
# Train Loss: 0.7468, Train Acc: 0.9973, Test  Loss: 0.7589, Test  Acc: 0.9836
# Epoch [93/100]
# Train Loss: 0.7470, Train Acc: 0.9973, Test  Loss: 0.7612, Test  Acc: 0.9836
# Epoch [94/100]
# Train Loss: 0.7442, Train Acc: 1.0000, Test  Loss: 0.7628, Test  Acc: 0.9754
# Epoch [95/100]
# Train Loss: 0.7600, Train Acc: 0.9835, Test  Loss: 0.7643, Test  Acc: 0.9754
# Epoch [96/100]
# Train Loss: 0.7492, Train Acc: 0.9945, Test  Loss: 0.7625, Test  Acc: 0.9836
# Epoch [97/100]
# Train Loss: 0.7444, Train Acc: 1.0000, Test  Loss: 0.7616, Test  Acc: 0.9836
# Epoch [98/100]
# Train Loss: 0.7465, Train Acc: 0.9973, Test  Loss: 0.7543, Test  Acc: 0.9918
# Epoch [99/100]
# Train Loss: 0.7527, Train Acc: 0.9945, Test  Loss: 0.7829, Test  Acc: 0.9590
# Epoch [100/100]
# Train Loss: 0.7626, Train Acc: 0.9835, Test  Loss: 0.7737, Test  Acc: 0.9672

# %% [markdown]
# #### 绘制loss和accuracy的变化曲线

# %%
import matplotlib.pyplot as plt
# 绘制loss和accuracy的变化曲线
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), train_loss_list, label='Train Loss')
plt.plot(range(1, num_epochs+1), test_loss_list, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_acc_list, label='Train Accuracy')
plt.plot(range(1, num_epochs+1), test_acc_list, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()


from sklearn.metrics import classification_report
# 加载最佳模型
model.load_state_dict(torch.load("./models/vehicleType.pth"))

# 模型评估
model.eval()
predictions = []
labels_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        predictions.extend(predicted.cpu().numpy())
        labels_list.extend(labels.cpu().numpy())

print(classification_report(labels_list, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        34
#            1       1.00      1.00      1.00        30
#            2       0.96      1.00      0.98        25
#            3       1.00      0.97      0.98        33
#
#     accuracy                           0.99       122
#    macro avg       0.99      0.99      0.99       122
# weighted avg       0.99      0.99      0.99       122
