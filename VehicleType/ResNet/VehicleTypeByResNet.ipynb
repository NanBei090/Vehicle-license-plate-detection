# %%
'''
使用RestNet做车型分析
'''
# 导入包
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms

# %%
# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# 设置参数
num_classes = 4
LR = 0.001
num_epochs = 100

print(device)
# Out:
# cuda

# %% [markdown]
# #### 加载数据集

# %%
# 数据预处理
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
# Prepare the dataset and dataloader
dataset = ImageFolder('../TypeData', transform=transform)
train_size = int(0.75 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %% [markdown]
# #### 定义网络结构

# %%
import torchvision.models as models

class ResNet18(nn.Module):
    def __init__(self, num_classes):
        super(ResNet18, self).__init__()
        self.model = models.resnet18(weights=None)
        self.model.fc = nn.Linear(self.model.fc.in_features, num_classes)  # 修改最后一层

    def forward(self, x):
        return self.model(x)

# %%
model = ResNet18(num_classes).to(device)

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=LR)

# %% [markdown]
# #### 训练模型

# %%
import torch
import torch.nn as nn

model = model.to(device) 

train_loss_list = []
train_acc_list = []
test_loss_list = []
test_acc_list = []
best_acc = 0

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    train_correct = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_correct += (predicted == labels).sum().item()

    train_loss /= len(train_loader)
    train_acc = train_correct / len(train_dataset)
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    # ---------- 验证 ----------
    model.eval()
    test_loss = 0
    test_correct = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            test_correct += (predicted == labels).sum().item()

    test_loss /= len(test_loader)
    test_acc = test_correct / len(test_dataset)
    test_loss_list.append(test_loss)
    test_acc_list.append(test_acc)

    print(f"Epoch [{epoch+1}/{num_epochs}]")
    print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test  Loss: {test_loss:.4f}, Test  Acc: {test_acc:.4f}")

    # ---------- 保存最优模型 ----------
    if test_acc > best_acc:
        best_acc = test_acc
        torch.save(model.state_dict(), './models/ResNet_best_model.pth')
# Out:
# Epoch [1/100]
# Train Loss: 0.5735, Train Acc: 0.8049, Test  Loss: 0.3691, Test  Acc: 0.8689
# Epoch [2/100]
# Train Loss: 0.2004, Train Acc: 0.9258, Test  Loss: 0.1359, Test  Acc: 0.9590
# Epoch [3/100]
# Train Loss: 0.2408, Train Acc: 0.9231, Test  Loss: 0.1203, Test  Acc: 0.9672
# Epoch [4/100]
# Train Loss: 0.1296, Train Acc: 0.9643, Test  Loss: 0.0727, Test  Acc: 0.9754
# Epoch [5/100]
# Train Loss: 0.0665, Train Acc: 0.9808, Test  Loss: 0.1201, Test  Acc: 0.9672
# Epoch [6/100]
# Train Loss: 0.0472, Train Acc: 0.9863, Test  Loss: 0.0668, Test  Acc: 0.9918
# Epoch [7/100]
# Train Loss: 0.0688, Train Acc: 0.9808, Test  Loss: 0.0658, Test  Acc: 0.9836
# Epoch [8/100]
# Train Loss: 0.0257, Train Acc: 0.9918, Test  Loss: 0.0788, Test  Acc: 0.9754
# Epoch [9/100]
# Train Loss: 0.0242, Train Acc: 0.9835, Test  Loss: 0.1995, Test  Acc: 0.9590
# Epoch [10/100]
# Train Loss: 0.0713, Train Acc: 0.9753, Test  Loss: 0.1004, Test  Acc: 0.9754
# Epoch [11/100]
# Train Loss: 0.0304, Train Acc: 0.9918, Test  Loss: 0.0558, Test  Acc: 0.9918
# Epoch [12/100]
# Train Loss: 0.0316, Train Acc: 0.9890, Test  Loss: 0.0465, Test  Acc: 0.9836
# Epoch [13/100]
# Train Loss: 0.0268, Train Acc: 0.9945, Test  Loss: 0.0561, Test  Acc: 0.9754
# Epoch [14/100]
# Train Loss: 0.0247, Train Acc: 0.9890, Test  Loss: 0.1026, Test  Acc: 0.9672
# Epoch [15/100]
# Train Loss: 0.0368, Train Acc: 0.9863, Test  Loss: 0.1017, Test  Acc: 0.9672
# Epoch [16/100]
# Train Loss: 0.0290, Train Acc: 0.9890, Test  Loss: 0.1928, Test  Acc: 0.9590
# Epoch [17/100]
# Train Loss: 0.0623, Train Acc: 0.9808, Test  Loss: 0.0794, Test  Acc: 0.9836
# Epoch [18/100]
# Train Loss: 0.0143, Train Acc: 0.9945, Test  Loss: 0.0608, Test  Acc: 0.9754
# Epoch [19/100]
# Train Loss: 0.0341, Train Acc: 0.9918, Test  Loss: 0.0933, Test  Acc: 0.9672
# Epoch [20/100]
# Train Loss: 0.0085, Train Acc: 1.0000, Test  Loss: 0.0773, Test  Acc: 0.9836
# Epoch [21/100]
# Train Loss: 0.0160, Train Acc: 0.9973, Test  Loss: 0.4326, Test  Acc: 0.8934
# Epoch [22/100]
# Train Loss: 0.0307, Train Acc: 0.9945, Test  Loss: 0.0224, Test  Acc: 0.9918
# Epoch [23/100]
# Train Loss: 0.0024, Train Acc: 1.0000, Test  Loss: 0.0332, Test  Acc: 0.9918
# Epoch [24/100]
# Train Loss: 0.0025, Train Acc: 1.0000, Test  Loss: 0.0195, Test  Acc: 0.9918
# Epoch [25/100]
# Train Loss: 0.0009, Train Acc: 1.0000, Test  Loss: 0.0242, Test  Acc: 0.9918
# Epoch [26/100]
# Train Loss: 0.0009, Train Acc: 1.0000, Test  Loss: 0.0297, Test  Acc: 0.9918
# Epoch [27/100]
# Train Loss: 0.0006, Train Acc: 1.0000, Test  Loss: 0.0275, Test  Acc: 0.9918
# Epoch [28/100]
# Train Loss: 0.0004, Train Acc: 1.0000, Test  Loss: 0.0281, Test  Acc: 0.9918
# Epoch [29/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.0293, Test  Acc: 0.9918
# Epoch [30/100]
# Train Loss: 0.0003, Train Acc: 1.0000, Test  Loss: 0.0282, Test  Acc: 0.9918
# Epoch [31/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.0298, Test  Acc: 0.9918
# Epoch [32/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.0292, Test  Acc: 0.9918
# Epoch [33/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.0304, Test  Acc: 0.9918
# Epoch [34/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.0308, Test  Acc: 0.9918
# Epoch [35/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.0278, Test  Acc: 0.9918
# Epoch [36/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.0281, Test  Acc: 0.9918
# Epoch [37/100]
# Train Loss: 0.0016, Train Acc: 1.0000, Test  Loss: 0.0572, Test  Acc: 0.9754
# Epoch [38/100]
# Train Loss: 0.0636, Train Acc: 0.9918, Test  Loss: 0.0812, Test  Acc: 0.9836
# Epoch [39/100]
# Train Loss: 0.0140, Train Acc: 0.9945, Test  Loss: 0.0522, Test  Acc: 0.9836
# Epoch [40/100]
# Train Loss: 0.0035, Train Acc: 0.9973, Test  Loss: 0.0684, Test  Acc: 0.9754
# Epoch [41/100]
# Train Loss: 0.0168, Train Acc: 0.9918, Test  Loss: 0.2676, Test  Acc: 0.9344
# Epoch [42/100]
# Train Loss: 0.1878, Train Acc: 0.9478, Test  Loss: 2.0211, Test  Acc: 0.8361
# Epoch [43/100]
# Train Loss: 0.2851, Train Acc: 0.9176, Test  Loss: 0.3151, Test  Acc: 0.9344
# Epoch [44/100]
# Train Loss: 0.1142, Train Acc: 0.9725, Test  Loss: 0.1515, Test  Acc: 0.9508
# Epoch [45/100]
# Train Loss: 0.1013, Train Acc: 0.9670, Test  Loss: 0.1520, Test  Acc: 0.9672
# Epoch [46/100]
# Train Loss: 0.0338, Train Acc: 0.9918, Test  Loss: 0.0698, Test  Acc: 0.9836
# Epoch [47/100]
# Train Loss: 0.0198, Train Acc: 0.9890, Test  Loss: 0.1247, Test  Acc: 0.9754
# Epoch [48/100]
# Train Loss: 0.0074, Train Acc: 1.0000, Test  Loss: 0.0832, Test  Acc: 0.9836
# Epoch [49/100]
# Train Loss: 0.0064, Train Acc: 0.9973, Test  Loss: 0.0886, Test  Acc: 0.9836
# Epoch [50/100]
# Train Loss: 0.0014, Train Acc: 1.0000, Test  Loss: 0.0886, Test  Acc: 0.9836
# Epoch [51/100]
# Train Loss: 0.0011, Train Acc: 1.0000, Test  Loss: 0.0986, Test  Acc: 0.9836
# Epoch [52/100]
# Train Loss: 0.0019, Train Acc: 1.0000, Test  Loss: 0.0975, Test  Acc: 0.9836
# Epoch [53/100]
# Train Loss: 0.0008, Train Acc: 1.0000, Test  Loss: 0.0955, Test  Acc: 0.9836
# Epoch [54/100]
# Train Loss: 0.0003, Train Acc: 1.0000, Test  Loss: 0.0990, Test  Acc: 0.9836
# Epoch [55/100]
# Train Loss: 0.0025, Train Acc: 1.0000, Test  Loss: 0.0833, Test  Acc: 0.9754
# Epoch [56/100]
# Train Loss: 0.0011, Train Acc: 1.0000, Test  Loss: 0.0800, Test  Acc: 0.9754
# Epoch [57/100]
# Train Loss: 0.0005, Train Acc: 1.0000, Test  Loss: 0.0905, Test  Acc: 0.9836
# Epoch [58/100]
# Train Loss: 0.0004, Train Acc: 1.0000, Test  Loss: 0.1027, Test  Acc: 0.9836
# Epoch [59/100]
# Train Loss: 0.0004, Train Acc: 1.0000, Test  Loss: 0.1044, Test  Acc: 0.9836
# Epoch [60/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1078, Test  Acc: 0.9836
# Epoch [61/100]
# Train Loss: 0.0008, Train Acc: 1.0000, Test  Loss: 0.1060, Test  Acc: 0.9836
# Epoch [62/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1099, Test  Acc: 0.9836
# Epoch [63/100]
# Train Loss: 0.0003, Train Acc: 1.0000, Test  Loss: 0.1032, Test  Acc: 0.9836
# Epoch [64/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1072, Test  Acc: 0.9836
# Epoch [65/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1078, Test  Acc: 0.9836
# Epoch [66/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1063, Test  Acc: 0.9836
# Epoch [67/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1082, Test  Acc: 0.9836
# Epoch [68/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1099, Test  Acc: 0.9836
# Epoch [69/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1153, Test  Acc: 0.9836
# Epoch [70/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1094, Test  Acc: 0.9836
# Epoch [71/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1111, Test  Acc: 0.9836
# Epoch [72/100]
# Train Loss: 0.0003, Train Acc: 1.0000, Test  Loss: 0.1090, Test  Acc: 0.9836
# Epoch [73/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1105, Test  Acc: 0.9836
# Epoch [74/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1142, Test  Acc: 0.9836
# Epoch [75/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1150, Test  Acc: 0.9836
# Epoch [76/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1156, Test  Acc: 0.9836
# Epoch [77/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1144, Test  Acc: 0.9836
# Epoch [78/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1152, Test  Acc: 0.9836
# Epoch [79/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1061, Test  Acc: 0.9836
# Epoch [80/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1127, Test  Acc: 0.9836
# Epoch [81/100]
# Train Loss: 0.0002, Train Acc: 1.0000, Test  Loss: 0.1162, Test  Acc: 0.9836
# Epoch [82/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1209, Test  Acc: 0.9836
# Epoch [83/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1158, Test  Acc: 0.9836
# Epoch [84/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1176, Test  Acc: 0.9836
# Epoch [85/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1070, Test  Acc: 0.9836
# Epoch [86/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1134, Test  Acc: 0.9836
# Epoch [87/100]
# Train Loss: 0.0000, Train Acc: 1.0000, Test  Loss: 0.1233, Test  Acc: 0.9836
# Epoch [88/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1175, Test  Acc: 0.9836
# Epoch [89/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1195, Test  Acc: 0.9836
# Epoch [90/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1133, Test  Acc: 0.9836
# Epoch [91/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1191, Test  Acc: 0.9836
# Epoch [92/100]
# Train Loss: 0.0000, Train Acc: 1.0000, Test  Loss: 0.1200, Test  Acc: 0.9836
# Epoch [93/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1199, Test  Acc: 0.9836
# Epoch [94/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1215, Test  Acc: 0.9836
# Epoch [95/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1268, Test  Acc: 0.9836
# Epoch [96/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1212, Test  Acc: 0.9836
# Epoch [97/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1187, Test  Acc: 0.9836
# Epoch [98/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1277, Test  Acc: 0.9836
# Epoch [99/100]
# Train Loss: 0.0000, Train Acc: 1.0000, Test  Loss: 0.1221, Test  Acc: 0.9836
# Epoch [100/100]
# Train Loss: 0.0001, Train Acc: 1.0000, Test  Loss: 0.1247, Test  Acc: 0.9836

# %% [markdown]
# #### 绘制loss和accuracy的变化曲线

# %%
import matplotlib.pyplot as plt
# 绘制loss和accuracy的变化曲线
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), train_loss_list, label='Train Loss')
plt.plot(range(1, num_epochs+1), test_loss_list, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_acc_list, label='Train Accuracy')
plt.plot(range(1, num_epochs+1), test_acc_list, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()


from sklearn.metrics import classification_report
# 加载最佳模型
model.load_state_dict(torch.load("./models/ResNet_best_model.pth"))

# 模型评估
model.eval()
predictions = []
labels_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        predictions.extend(predicted.cpu().numpy())
        labels_list.extend(labels.cpu().numpy())

print(classification_report(labels_list, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        30
#            1       1.00      1.00      1.00        34
#            2       0.97      1.00      0.99        33
#            3       1.00      0.96      0.98        25
#
#     accuracy                           0.99       122
#    macro avg       0.99      0.99      0.99       122
# weighted avg       0.99      0.99      0.99       122
